# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from sklearn.linear_model import LinearRegression

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
merged_df = pd.merge(study_results, mouse_metadata, on='Mouse ID')

# Display the data table for preview
merged_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
merged_df["Mouse ID"].nunique()
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
merged_df[merged_df.duplicated(keep=False)]
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0                45.0                 0     Propriva
# 861     g989          0                45.0                 0     Propriva
#
#         Sex  Age_months  Weight (g)
# 860  Female          21          26
# 861  Female          21          26

# %%
# Optional: Get all the data for the duplicate mouse ID. 
merged_df.loc[merged_df["Mouse ID"] == 'g989']
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
# 870     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
dropped_df = merged_df.drop(merged_df[merged_df['Mouse ID'] == 'g989'].index)
dropped_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
dropped_df["Mouse ID"].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

# Create grouped DF object
summary_df = dropped_df.groupby(['Drug Regimen'])

# Calculate based on Tumor Volume field.
mean = summary_df['Tumor Volume (mm3)'].mean()
std = summary_df['Tumor Volume (mm3)'].std()
median = summary_df['Tumor Volume (mm3)'].median()
var = summary_df['Tumor Volume (mm3)'].var()
sem = summary_df['Tumor Volume (mm3)'].sem()

# Populate new DF with calculated above using the column names in the example
summary_df2 = pd.DataFrame({
                        "Mean Tumor Volume": mean,
                        "Median Tumor Volume" : median,
                        "Tumor Volume Variance" : var,
                        "Tumor Volume Std. Dev." : std,
                        "Tumor Volume Std. Err." : sem
                        })

# Print
summary_df2
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line

# https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.core.groupby.DataFrameGroupBy.agg.html

summary_df_agg = dropped_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg(['mean','median','var','std', 'sem']).reset_index()
summary_df_agg
# Out:
#   Drug Regimen       mean     median        var       std       sem
# 0    Capomulin  40.675741  41.557809  24.947764  4.994774  0.329346
# 1     Ceftamin  52.591172  51.776157  39.290177  6.268188  0.469821
# 2    Infubinol  52.884795  51.820584  43.128684  6.567243  0.492236
# 3     Ketapril  55.235638  53.698743  68.553577  8.279709  0.603860
# 4     Naftisol  54.331565  52.509285  66.173479  8.134708  0.596466
# 5      Placebo  54.033581  52.288934  61.168083  7.821003  0.581331
# 6     Propriva  52.320930  50.446266  43.852013  6.622085  0.544332
# 7     Ramicane  40.216745  40.673236  23.486704  4.846308  0.320955
# 8     Stelasyn  54.233149  52.431737  59.450562  7.710419  0.573111
# 9    Zoniferol  53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
bar_df = summary_df['Timepoint'].count()

#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html
bar = bar_df.plot.bar(x='Drug Regimen', y='Timepoint', rot=90)
bar.set_ylabel("# of Observed Mouse Timpoints")
# Out:
# Text(0, 0.5, '# of Observed Mouse Timpoints')

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
plt.bar(bar_df.index, bar_df.sort_values(ascending=False))
plt.xticks(rotation="vertical")
plt.ylabel("# of Observed Mouse Timpoints")
plt.xlabel("Drug Regimen")

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

#https://www.statology.org/pandas-pie-chart/

gender_df = dropped_df.groupby(['Sex'])['Sex'].count().plot(kind='pie', autopct='%1.01f%%')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

#https://www.w3schools.com/python/matplotlib_pie_charts.asp
#https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html

plt.pie(dropped_df.groupby(['Sex'])['Sex'].count(), labels=['Female', 'Male'], autopct='%1.01f%%')
plt.ylabel("Sex")

plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


max_df= dropped_df.groupby(['Mouse ID'])['Timepoint'].max()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint

merge_df = pd.merge(dropped_df, max_df, on=('Mouse ID', 'Timepoint'), how = 'right')
merge_df
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419                 2    Infubinol
# 1       a251         45           65.525743                 1    Infubinol
# 2       a262         45           70.717621                 4      Placebo
# 3       a275         45           62.999356                 3     Ceftamin
# 4       a366         30           63.440686                 1     Stelasyn
# ..       ...        ...                 ...               ...          ...
# 243     z435         10           48.710661                 0     Propriva
# 244     z578         45           30.638696                 0     Ramicane
# 245     z581         45           62.754451                 3    Infubinol
# 246     z795         45           65.741070                 3     Naftisol
# 247     z969         45           73.867845                 4     Naftisol
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
# Create empty list to fill with tumor vol data (for plotting)
drugs = {'Capomulin':[], 
         'Ramicane':[], 
         'Infubinol':[], 
         'Ceftamin':[]}


drugList = []
for drug in drugs.keys():
    drugList.append(drug)
    

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
for d in drugs:
    for index, mouse in merge_df.iterrows():
        if mouse['Drug Regimen'] == d:
            drugs[d].append(mouse['Tumor Volume (mm3)'])
    
    # add subset
subset_df = pd.DataFrame(drugs)
subset_df
# Out:
#     Capomulin   Ramicane  Infubinol   Ceftamin
# 0   38.982878  38.407618  67.973419  62.999356
# 1   38.939633  43.047543  65.525743  45.000000
# 2   30.485985  38.810366  57.031862  56.057749
# 3   37.074024  32.978522  66.083066  55.742829
# 4   40.159220  38.342008  72.226731  48.722078
# 5   47.685963  33.397653  36.321346  47.784682
# 6   37.311846  37.311236  60.969711  61.849023
# 7   38.125164  40.659006  62.435404  68.923185
# 8   38.753265  29.128472  60.918767  67.748662
# 9   41.483008  33.562402  67.289621  57.918381
# 10  38.846876  36.374510  66.196912  46.784535
# 11  28.430964  31.560470  62.117279  59.851956
# 12  33.329098  36.134852  47.010364  64.299830
# 13  46.539206  22.050126  60.165180  59.741901
# 14  32.377357  30.564625  55.629428  61.433892
# 15  41.581521  31.095335  45.699331  64.192341
# 16  23.343598  45.220869  54.656549  45.000000
# 17  40.728578  36.561652  55.650681  52.925348
# 18  34.455298  37.225650  46.250112  45.000000
# ...

# %%
for dl in drugList:
    Q1 = subset_df[dl].quantile(0.25)
    Q3 = subset_df[dl].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - (1.5 * IQR)
    upper = Q3 + (1.5 * IQR)
    print(f'{dl}\'s IQR: Lower {lower} and Upper {upper}')
# Out:
# Capomulin's IQR: Lower 20.70456164999999 and Upper 51.83201549
# Ramicane's IQR: Lower 17.912664470000003 and Upper 54.30681135
# Infubinol's IQR: Lower 36.83290494999999 and Upper 82.74144559000001
# Ceftamin's IQR: Lower 25.355449580000002 and Upper 87.66645829999999

# %%
# Determine outliers using upper and lower bounds
for dl in drugList:
    print(f'{dl}\'s potential outliers: {subset_df[dl].max()} and {subset_df[dl].min()}')
# Out:
# Capomulin's potential outliers: 47.68596303 and 23.34359787
# Ramicane's potential outliers: 45.22086888 and 22.05012627
# Infubinol's potential outliers: 72.2267309 and 36.3213458
# Ceftamin's potential outliers: 68.92318457 and 45.0

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
subset_df.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

# Grab from DF that has each instance of the mouse data
line_df = merged_df.loc[merged_df["Mouse ID"] == "l509"]
line_df

# Assign values to axes and plot data
x_axis = line_df["Timepoint"]
y_axis = line_df["Tumor Volume (mm3)"]

plt.plot(x_axis, y_axis)

# Assign title and labels
plt.title('Capomulin treatment of mouse I509')

plt.xlabel('Timepoint (Days)')
plt.ylabel('Tumor Volume (mm3)')

plt.savefig('linechart')
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
# Grab from DF that has each instance of the mouse data
capo_df = merged_df.loc[merged_df["Drug Regimen"] == "Capomulin"]
#capo_df

# Create DF with values for each Mouse ID - Average for Tumor and Weight for mouse (not really the mean, but it works here)
average_tumor_df = capo_df.groupby('Mouse ID')['Tumor Volume (mm3)'].mean().reset_index()
average_weight_df = capo_df.groupby('Mouse ID')['Weight (g)'].mean().reset_index()

# Merge the two DF's
average_merge_df = pd.merge(average_weight_df, average_tumor_df, on = 'Mouse ID')

# Assign values to axes and plot data
x_axis = average_merge_df ["Weight (g)"]
y_axis = average_merge_df ["Tumor Volume (mm3)"]

# Assign title and labels
plt.title('Mouse weight vs. the average observed tumor volume for Capomulin regimen')

plt.ylabel('Average Tumor Volume (mm3)')
plt.xlabel('Weight (g)')

plt.scatter(x_axis, y_axis)

# plt.savefig('scatter')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
correlation = np.corrcoef(average_tumor_df["Tumor Volume (mm3)"],average_weight_df["Weight (g)"])
print(result)
# Out:
# [[1.         0.84193634]
#  [0.84193634 1.        ]]

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
regressor = LinearRegression()
regressor.fit(average_weight_df[["Weight (g)"]],average_tumor_df[["Tumor Volume (mm3)"]])

y_pred = regressor.predict(average_weight_df[["Weight (g)"]])
# Out:
# LinearRegression()

# %%
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, regressor.predict(average_weight_df[["Weight (g)"]]), color = 'red')
# Assign title and labels

plt.ylabel('Average Tumor Volume (mm3)')
plt.xlabel('Weight (g)')
plt.show()
